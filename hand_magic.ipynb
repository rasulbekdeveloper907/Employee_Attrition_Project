# %% [markdown]
# # 01_Project_Overview.md
#
# # 🪄 Hand Magic Project
#
# ## Muallif
#
# Ushbu loyiha **OpenCV**, **MediaPipe** va **NumPy** yordamida yaratilgan interaktiv Computer Vision loyihasi hisoblanadi.
#
# Foydalanuvchi qo'l harakati orqali ekranda sehrli (magic) effektlar hosil qiladi.
#
# ---
#
# # Loyiha maqsadi
#
# Loyihaning asosiy maqsadi:
#
# - Webcam orqali qo'lni aniqlash
# - Ko'rsatkich barmoq (Index Finger) ni kuzatish
# - Barmoq harakatini chizish
# - Pinch (bosh barmoq + ko'rsatkich barmoq) ni aniqlash
# - Sehrli geometrik shakllar yaratish
# - Glow (yorug'lik) effektini qo'shish
# - Starfield (yulduzli fon) yaratish
#
# Natijada foydalanuvchi ekranda xuddi sehrgar kabi effektlar yaratadi.
#
# ---
#
# # Ishlash prinsipi
#
# Programma quyidagi ketma-ketlikda ishlaydi.
#
# ```
# Webcam
#    │
#    ▼
# OpenCV
#    │
#    ▼
# Frame olish
#    │
#    ▼
# MediaPipe Hands
#    │
#    ▼
# 21 ta Landmark
#    │
#    ▼
# Index Finger
#    │
#    ▼
# Trail chizish
#    │
#    ▼
# Pinch Detection
#    │
#    ▼
# Wire Shape yaratish
#    │
#    ▼
# Glow Effect
#    │
#    ▼
# Monitor
# ```
#
# ---
#
# # Ishlatilgan kutubxonalar
#
# ## OpenCV
#
# ```python
# import cv2
# ```
#
# OpenCV Computer Vision kutubxonasi.
#
# Vazifalari:
#
# - Webcam ochish
# - Video olish
# - Chiziq chizish
# - Doira chizish
# - Ellipse
# - Blur
# - RGB ↔ BGR
# - Window yaratish
#
# ---
#
# ## NumPy
#
# ```python
# import numpy as np
# ```
#
# Matritsalar bilan ishlash uchun.
#
# Masalan
#
# ```python
# canvas = np.zeros_like(frame)
# ```
#
# frame bilan bir xil o'lchamdagi qora rasm yaratadi.
#
# ---
#
# ## MediaPipe
#
# ```python
# import mediapipe as mp
# ```
#
# Google tomonidan ishlab chiqilgan AI kutubxonasi.
#
# Qo'lni avtomatik aniqlaydi.
#
# Natijada 21 ta landmark beradi.
#
# Masalan
#
# ```
# 0  Wrist
#
# 4  Thumb Tip
#
# 8  Index Finger Tip
#
# 12 Middle Finger
#
# 16 Ring Finger
#
# 20 Pinky
# ```
#
# ---
#
# ## math
#
# ```python
# import math
# ```
#
# Matematik hisoblar uchun.
#
# Masalan
#
# ```python
# distance = math.hypot(x1-x2,y1-y2)
# ```
#
# Ikki nuqta orasidagi masofani hisoblaydi.
#
# ---
#
# ## random
#
# ```python
# import random
# ```
#
# Tasodifiy sonlar yaratadi.
#
# Masalan
#
# ```python
# random.uniform(0,960)
# ```
#
# 0 va 960 oralig'ida son hosil qiladi.
#
# Bu yulduzlarni tasodifiy joylashtirish uchun ishlatiladi.
#
# ---
#
# ## time
#
# ```python
# import time
# ```
#
# Vaqt bilan ishlaydi.
#
# Masalan
#
# ```python
# time.time()
# ```
#
# Hozirgi vaqtni sekundlarda qaytaradi.
#
# Bu:
#
# - Animatsiya
# - Fade
# - Rotation
# - Lifetime
#
# uchun ishlatiladi.
#
# ---
#
# ## deque
#
# ```python
# from collections import deque
# ```
#
# Oddiy list emas.
#
# Queue (navbat) hisoblanadi.
#
# Misol:
#
# ```
# deque
#
# 1
# 2
# 3
# 4
# 5
# ```
#
# Yangi element qo'shilsa
#
# ```
# 2
# 3
# 4
# 5
# 6
# ```
#
# Eski element avtomatik o'chadi.
#
# Trail yaratishda juda qulay.
#
# ---
#
# # Dastur sozlamalari
#
# ## Kamera
#
# ```python
# CAM_INDEX = 0
# ```
#
# 0
#
# birinchi webcam.
#
# Agar ikkita kamera bo'lsa
#
# ```
# 0
#
# 1
#
# 2
# ```
#
# bo'lishi mumkin.
#
# ---
#
# ## Oyna o'lchami
#
# ```python
# FRAME_W = 960
# FRAME_H = 540
# ```
#
# Video o'lchami.
#
# ```
# 960 px
#
# ×
#
# 540 px
# ```
#
# ---
#
# ## Yulduzlar soni
#
# ```python
# NUM_STARS = 160
# ```
#
# Fon uchun
#
# 160 ta yulduz yaratiladi.
#
# Ko'paytirsa
#
# ```
# 300
# ```
#
# yanada chiroyli bo'ladi.
#
# Lekin FPS kamayadi.
#
# ---
#
# ## Trail uzunligi
#
# ```python
# TRAIL_MAX_LEN = 40
# ```
#
# Barmoq harakati nechta nuqta saqlanishini bildiradi.
#
# Masalan
#
# ```
# •
#
# ••
#
# •••
#
# ••••
# ```
#
# 40 ta nuqtagacha.
#
# Keyin eskilari o'chib boradi.
#
# ---
#
# ## Pinch Threshold
#
# ```python
# PINCH_THRESHOLD = 40
# ```
#
# Pinch degani:
#
# ```
# Thumb
#
#       ●
#
#         \
#
#          \
#
#           ●
#
# Index
# ```
#
# Agar ular orasidagi masofa
#
# 40 pixeldan kichik bo'lsa
#
# Pinch hisoblanadi.
#
# ---
#
# ## Cooldown
#
# ```python
# PINCH_COOLDOWN = 0.6
# ```
#
# Har safar pinch qilganda
#
# 0.6 sekund kutadi.
#
# Sababi
#
# Bir soniyada
#
# ```
# 100 ta
# ```
#
# shape yaralib ketmasligi kerak.
#
# ---
#
# ## Glow rangi
#
# ```python
# GLOW_COLOR = (255,220,60)
# ```
#
# OpenCV
#
# BGR format ishlatadi.
#
# ```
# Blue =255
#
# Green=220
#
# Red=60
# ```
#
# Natijada sariq-oltin rang hosil bo'ladi.
#
# ---
#
# ## Trail rangi
#
# ```python
# TRAIL_COLOR = (255,220,60)
# ```
#
# Barmoq orqasidan qoladigan iz.
#
# ---
#
# # Dastur ichidagi asosiy obyektlar
#
# ## Starfield
#
# Mas'ul:
#
# ⭐ Fonni yaratadi.
#
# ---
#
# ## WireShape
#
# Mas'ul:
#
# ⭕ Sehrli shakllarni yaratadi.
#
# ---
#
# ## MediaPipe Hands
#
# Mas'ul:
#
# ✋ Qo'lni topadi.
#
# ---
#
# ## Trail
#
# Mas'ul:
#
# ✨ Barmoq ortidan iz qoldiradi.
#
# ---
#
# ## Glow Layer
#
# Mas'ul:
#
# 💡 Yorug'lik effektini yaratadi.
#
# ---
#
# # Dastur ishlash jarayoni
#
# ```
# Programma boshlanadi
#
# ↓
#
# Webcam ochiladi
#
# ↓
#
# Har bir frame olinadi
#
# ↓
#
# MediaPipe qo'lni topadi
#
# ↓
#
# Index Finger koordinatasi olinadi
#
# ↓
#
# Trail chiziladi
#
# ↓
#
# Thumb bilan masofa hisoblanadi
#
# ↓
#
# Pinch bo'lsa
#
# ↓
#
# WireShape yaratiladi
#
# ↓
#
# Glow qo'shiladi
#
# ↓
#
# Natija monitorga chiqariladi
#
# ↓
#
# Keyingi frame...
# ```
#
# ---
#
# # Ushbu loyihada foydalanilgan asosiy texnologiyalar
#
# | Texnologiya | Vazifasi |
# |------------|----------|
# | OpenCV | Kamera va chizish |
# | MediaPipe | Hand Tracking |
# | NumPy | Rasm matritsalari |
# | Math | Masofa va trigonometriya |
# | Random | Tasodifiy yulduzlar |
# | Time | Animatsiya va Lifetime |
# | deque | Trail saqlash |
#
# ---
#
# # Xulosa
#
# Bu loyiha bir nechta muhim Computer Vision texnologiyalarini birlashtiradi:
#
# - OpenCV yordamida kamera va grafika.
# - MediaPipe yordamida qo'lni real vaqtda aniqlash.
# - NumPy yordamida tasvirlarni boshqarish.
# - Glow va Blur yordamida vizual effektlar.
# - `deque` yordamida barmoq harakatining izi.
# - Pinch gesture orqali interaktiv sehrli shakllar yaratish.
#
# Keyingi dars **02_Background_and_Effects.md** bo'lib, unda `Starfield`, `Glow Effect` va `WireShape` klasslari qatorma-qator tushuntiriladi.

# %% [markdown]
# # 02_Background_and_Effects.md
#
# # 🌌 Background va Visual Effects
#
# Bu bo'limda quyidagi qismlarni o'rganamiz:
#
# - ⭐ Starfield klassi
# - ✨ Glow Effect
# - 🔷 WireShape klassi
# - 🧠 Animatsiya qanday ishlaydi
#
# ---
#
# # Starfield klassi
#
# Kod:
#
# ```python
# class Starfield:
# ```
#
# Bu klass ekrandagi **yulduzli fonni (Starfield)** yaratish uchun yozilgan.
#
# Har bir yulduz:
#
# - o'z koordinatasiga ega
# - o'z tezligiga ega
# - o'z radiusiga ega
# - o'z miltillash (twinkle) fazasiga ega
#
# Natijada fon jonli ko'rinadi.
#
# ---
#
# # Konstruktor (__init__)
#
# Kod:
#
# ```python
# def __init__(self, w, h, n_stars):
# ```
#
# Bu metod obyekt yaratilganda bir marta ishlaydi.
#
# Parametrlar:
#
# | Parametr | Ma'nosi |
# |----------|----------|
# | w | Ekran eni |
# | h | Ekran bo'yi |
# | n_stars | Yulduzlar soni |
#
# ---
#
# ## O'lchamlarni saqlash
#
# ```python
# self.w = w
# self.h = h
# ```
#
# Keyinchalik yulduzlarni chizishda kerak bo'ladi.
#
# Masalan
#
# ```
# 960 × 540
# ```
#
# ---
#
# # Yulduzlarni yaratish
#
# Kod:
#
# ```python
# self.stars = [
# ```
#
# Bu yerda **list** hosil qilinadi.
#
# Har bir element bitta yulduz.
#
# Masalan:
#
# ```python
# {
# "x":100,
# "y":250,
# "r":2,
# "speed":5,
# "phase":1.3
# }
# ```
#
# ---
#
# # x koordinatasi
#
# ```python
# "x": random.uniform(0,w)
# ```
#
# Tasodifiy
#
# ```
# 0
#
# ↓
#
# 960
# ```
#
# oralig'ida son hosil qiladi.
#
# Masalan
#
# ```
# 512.4
# ```
#
# ---
#
# # y koordinatasi
#
# ```python
# "y": random.uniform(0,h)
# ```
#
# Tasodifiy balandlik.
#
# Masalan
#
# ```
# 120
#
# 350
#
# 520
# ```
#
# ---
#
# # Radius
#
# ```python
# "r": random.uniform(0.5,1.8)
# ```
#
# Yulduz kattaligi.
#
# Masalan
#
# ```
# 0.6
#
# 1.1
#
# 1.8
# ```
#
# Radius katta bo'lsa
#
# ⭐ kattaroq chiqadi.
#
# ---
#
# # Speed
#
# ```python
# "speed": random.uniform(2,10)
# ```
#
# Har bir yulduz har xil tezlikda tushadi.
#
# Masalan
#
# ```
# 2 px
#
# 5 px
#
# 9 px
# ```
#
# Shuning uchun fon tabiiy ko'rinadi.
#
# ---
#
# # Phase
#
# ```python
# "phase": random.uniform(0,math.pi*2)
# ```
#
# Bu juda muhim parametr.
#
# Twinkle animatsiyasini boshqaradi.
#
# Har bir yulduz:
#
# ```
# har xil vaqtda
#
# yorishadi
#
# so'nadi
# ```
#
# Agar phase bo'lmasa
#
# hamma yulduzlar bir vaqtda miltillaydi.
#
# Bu esa sun'iy ko'rinadi.
#
# ---
#
# # for _ in range(n_stars)
#
# Kod:
#
# ```python
# for _ in range(n_stars)
# ```
#
# Masalan
#
# ```
# 160
# ```
#
# bo'lsa
#
# 160 ta dictionary yaratiladi.
#
# Natijada
#
# ```
# stars
#
# ↓
#
# [
# star1,
#
# star2,
#
# star3,
#
# ...
#
# star160
# ]
# ```
#
# ---
#
# # draw()
#
# Kod
#
# ```python
# def draw(self,canvas):
# ```
#
# Bu funksiya
#
# har bir frame ishlaydi.
#
# Taxminan
#
# ```
# 30 FPS
#
# 60 FPS
# ```
#
# bo'lishi mumkin.
#
# ---
#
# # Hozirgi vaqt
#
# ```python
# t = time.time()
# ```
#
# Masalan
#
# ```
# 1753265000.15
# ```
#
# sekund.
#
# Bu animatsiya uchun kerak.
#
# ---
#
# # Barcha yulduzlarni aylanish
#
# ```python
# for s in self.stars:
# ```
#
# Har bir yulduz alohida chiziladi.
#
# ---
#
# # Twinkle
#
# Kod
#
# ```python
# twinkle = 0.5 + 0.5 * math.sin(...)
# ```
#
# Bu sinus funksiyasi.
#
# Sinus:
#
# ```
# -1
#
# ↓
#
# 1
# ```
#
# orasida yuradi.
#
# Biz uni
#
# ```
# 0
#
# ↓
#
# 1
# ```
#
# ga o'tkazamiz.
#
# Natijada
#
# ```
# yorug'lik
#
# ↑
#
# ↓
#
# ↑
#
# ↓
#
# ↑
# ```
#
# hosil bo'ladi.
#
# ---
#
# # Brightness
#
# Kod
#
# ```python
# brightness = int(120+135*twinkle)
# ```
#
# Natija
#
# ```
# 120
#
# ↓
#
# 255
# ```
#
# oralig'ida.
#
# Shunday qilib
#
# ⭐ ba'zida xira
#
# ⭐ ba'zida yorqin
#
# ko'rinadi.
#
# ---
#
# # Rang
#
# Kod
#
# ```python
# color=(brightness,brightness,brightness)
# ```
#
# Barcha qiymatlar teng.
#
# Natija
#
# ```
# oq rang
# ```
#
# hosil bo'ladi.
#
# ---
#
# # Circle
#
# Kod
#
# ```python
# cv2.circle(...)
# ```
#
# Bu yulduzni chizadi.
#
# Parametrlar
#
# | Parametr | Ma'nosi |
# |-----------|----------|
# | canvas | qayerga chizish |
# | x,y | koordinata |
# | radius | kattalik |
# | color | rang |
# | -1 | ichi to'ldirilgan |
#
# ---
#
# # Pastga tushirish
#
# Kod
#
# ```python
# s["y"] += s["speed"]*0.02
# ```
#
# Har frame
#
# ```
# Y
#
# ↓
#
# ↓
#
# ↓
#
# ```
#
# pastga tushadi.
#
# Tezligi
#
# speed ga bog'liq.
#
# ---
#
# # Ekrandan chiqsa
#
# Kod
#
# ```python
# if s["y"]>self.h:
# ```
#
# Masalan
#
# ```
# 541
# ```
#
# bo'lsa
#
# ekrandan chiqib ketgan.
#
# ---
#
# # Tepaga qaytarish
#
# ```python
# s["y"]=0
# ```
#
# Yulduz yana tepada paydo bo'ladi.
#
# ---
#
# # x ni yangilash
#
# ```python
# s["x"]=random.uniform(0,self.w)
# ```
#
# Har safar boshqa joydan tushadi.
#
# Natijada
#
# fon bir xil ko'rinmaydi.
#
# ---
#
# # Glow Effect
#
# Kod
#
# ```python
# def draw_glow_line(...)
# ```
#
# Bu oddiy chiziq emas.
#
# Glow hosil qilish uchun ishlatiladi.
#
# Ichida
#
# ```python
# cv2.line(...)
# ```
#
# ishlaydi.
#
# ---
#
# # cv2.line
#
# Parametrlar
#
# | Parametr | Vazifasi |
# |-----------|----------|
# | pt1 | Boshlanish nuqtasi |
# | pt2 | Tugash nuqtasi |
# | color | Rang |
# | thickness | Qalinlik |
# | LINE_AA | Yumshoq chiziq |
#
# LINE_AA bo'lmasa
#
# chiziq tishli chiqadi.
#
# ---
#
# # add_glow()
#
# Kod
#
# ```python
# def add_glow(...)
# ```
#
# Bu loyiha ichidagi eng muhim effektlardan biri.
#
# ---
#
# # Gaussian Blur
#
# Kod
#
# ```python
# blurred = cv2.GaussianBlur(...)
# ```
#
# Blur nima?
#
# Oldin
#
# ```
# ********
# ```
#
# Blur
#
# ```
# ~~~~~~~
# ```
#
# Natijada
#
# yorug'lik tarqaladi.
#
# ---
#
# # addWeighted
#
# Kod
#
# ```python
# cv2.addWeighted(...)
# ```
#
# Ikki rasmni qo'shadi.
#
# ```
# Original
#
# +
#
# Blur
#
# =
#
# Glow
# ```
#
# Shuning uchun
#
# chiroyli neon effekt hosil bo'ladi.
#
# ---
#
# # WireShape klassi
#
# Kod
#
# ```python
# class WireShape:
# ```
#
# Bu klass
#
# Sehrli geometrik shakllarni yaratadi.
#
# Masalan
#
# ⭕ Ring
#
# ⬡ Hexagon
#
# ---
#
# # Konstruktor
#
# ```python
# def __init__(...)
# ```
#
# Har yangi shape yaralganda ishlaydi.
#
# ---
#
# # Center
#
# ```python
# self.center=center
# ```
#
# Shape markazi.
#
# Masalan
#
# ```
# (400,250)
# ```
#
# ---
#
# # Birth
#
# ```python
# self.birth=time.time()
# ```
#
# Shape yaratilgan vaqt.
#
# ---
#
# # Lifetime
#
# ```python
# self.lifetime=4.0
# ```
#
# Shape
#
# 4 sekund yashaydi.
#
# Keyin yo'qoladi.
#
# ---
#
# # Kind
#
# ```python
# ring
#
# yoki
#
# poly
# ```
#
# Tasodifiy tanlanadi.
#
# ---
#
# # Rotation Speed
#
# ```python
# self.rot_speed
# ```
#
# Har bir shape
#
# har xil tezlikda aylanadi.
#
# Masalan
#
# ```
# 1.1
#
# -1.5
#
# 2.0
# ```
#
# Manfiy bo'lsa
#
# teskari tomonga aylanadi.
#
# ---
#
# # alive()
#
# Kod
#
# ```python
# return (time.time()-self.birth)<self.lifetime
# ```
#
# Agar
#
# ```
# 4 sekund
# ```
#
# o'tmagan bo'lsa
#
# True qaytaradi.
#
# Aks holda
#
# False.
#
# ---
#
# # draw()
#
# Bu funksiya
#
# shape ni chizadi.
#
# Har frame ishlaydi.
#
# ---
#
# # Age
#
# ```python
# age=time.time()-self.birth
# ```
#
# Shape necha sekund yashaganini hisoblaydi.
#
# ---
#
# # Fade
#
# ```python
# fade=1-age/lifetime
# ```
#
# Masalan
#
# ```
# 1.0
#
# ↓
#
# 0.7
#
# ↓
#
# 0.3
#
# ↓
#
# 0
# ```
#
# Natijada shape asta-sekin yo'qoladi.
#
# ---
#
# # Rotation
#
# ```python
# angle=age*self.rot_speed
# ```
#
# Har frame
#
# shape biroz aylanadi.
#
# ---
#
# # Ring
#
# ```python
# cv2.ellipse(...)
# ```
#
# Tashqi halqa.
#
# ---
#
# # Circle
#
# ```python
# cv2.circle(...)
# ```
#
# Ichki halqa.
#
# Natijada
#
# ```
# ⭕
# ```
#
# ko'rinishi hosil bo'ladi.
#
# ---
#
# # Polygon
#
# Agar
#
# ```python
# kind=="poly"
# ```
#
# bo'lsa
#
# 6 qirrali figura chiziladi.
#
# ---
#
# # Hexagon
#
# ```python
# for i in range(6):
# ```
#
# Har bir burchak hisoblanadi.
#
# ```
# ⬡
# ```
#
# ---
#
# # cos va sin
#
# ```python
# math.cos()
#
# math.sin()
# ```
#
# Har bir burchak koordinatasini topadi.
#
# ---
#
# # Chiziqlar
#
# ```python
# cv2.line(...)
# ```
#
# Nuqtalarni birlashtirib
#
# olti burchak hosil qiladi.
#
# ---
#
# # Ushbu bo'lim yakuni
#
# Bu bo'limda quyidagilarni o'rgandik:
#
# ✅ Starfield qanday yaratiladi
#
# ✅ Yulduzlar nima uchun miltillaydi
#
# ✅ Glow effekti qanday hosil qilinadi
#
# ✅ Gaussian Blur nima
#
# ✅ addWeighted nima
#
# ✅ WireShape qanday ishlaydi
#
# ✅ Ring va Polygon qanday chiziladi
#
# ✅ Fade va Rotation animatsiyasi qanday yaratiladi
#
# ---
#
# ## Keyingi bo'lim
#
# **03_Hand_Tracking.md**
#
# Unda quyidagilar batafsil tushuntiriladi:
#
# - MediaPipe Hands
# - 21 ta Landmark
# - Webcam
# - RGB Conversion
# - Hand Detection
# - Index Finger
# - Thumb
# - Pinch Detection
# - Trail (deque)
# - Masofa formulasi
# - Qo'l yo'qolganda nima bo'ladi

# %% [markdown]
# # 03_Hand_Tracking.md
#
# # ✋ Hand Tracking (MediaPipe Hands)
#
# Bu bo'limda quyidagilarni o'rganamiz:
#
# - MediaPipe Hands
# - Webcam
# - VideoCapture
# - RGB Conversion
# - Hand Landmark
# - Index Finger
# - Thumb
# - Pinch Detection
# - Trail
# - deque
# - Distance Formula
#
# ---
#
# # main() funksiyasi
#
# Kod
#
# ```python
# def main():
# ```
#
# Bu dastur boshlanadigan asosiy funksiya.
#
# Python quyidagi kodni ko'rganda:
#
# ```python
# if __name__ == "__main__":
#     main()
# ```
#
# `main()` funksiyasi ishga tushadi.
#
# ---
#
# # MediaPipe Hands yaratish
#
# Kod
#
# ```python
# mp_hands = mp.solutions.hands
# ```
#
# Bu MediaPipe ichidagi **Hands** modulini chaqiradi.
#
# MediaPipe quyidagilarni aniqlay oladi:
#
# - Face
# - Pose
# - Hands
# - Holistic
# - Selfie Segmentation
#
# Biz esa **Hands** modulidan foydalanamiz.
#
# ---
#
# # Hands obyekti
#
# Kod
#
# ```python
# hands = mp_hands.Hands(
#     max_num_hands=1,
#     min_detection_confidence=0.6,
#     min_tracking_confidence=0.6,
# )
# ```
#
# Bu AI modelini ishga tushiradi.
#
# ---
#
# ## max_num_hands
#
# ```python
# max_num_hands=1
# ```
#
# Bir vaqtning o'zida nechta qo'l aniqlanishini bildiradi.
#
# ```
# 1 → bitta qo'l
#
# 2 → ikkita qo'l
# ```
#
# ---
#
# ## min_detection_confidence
#
# ```python
# 0.6
# ```
#
# Qo'l topilganiga ishonch darajasi.
#
# ```
# 0.6 = 60%
# ```
#
# Agar modelning ishonchi 60% dan past bo'lsa, qo'l aniqlanmagan deb hisoblanadi.
#
# ---
#
# ## min_tracking_confidence
#
# ```python
# 0.6
# ```
#
# Qo'l topilgandan keyin uni kuzatish sifati.
#
# Qiymat katta bo'lsa:
#
# - aniqlik oshadi
# - lekin FPS biroz kamayadi.
#
# ---
#
# # Kamerani ochish
#
# Kod
#
# ```python
# cap = cv2.VideoCapture(CAM_INDEX)
# ```
#
# Bu webcamni ochadi.
#
# Agar
#
# ```python
# CAM_INDEX = 0
# ```
#
# bo'lsa birinchi kamera ishlatiladi.
#
# ---
#
# # Kamera o'lchami
#
# Kod
#
# ```python
# cap.set(cv2.CAP_PROP_FRAME_WIDTH, FRAME_W)
# cap.set(cv2.CAP_PROP_FRAME_HEIGHT, FRAME_H)
# ```
#
# Natijada video:
#
# ```
# 960 × 540
# ```
#
# o'lchamda olinadi.
#
# ---
#
# # Kamera tekshirish
#
# Kod
#
# ```python
# if not cap.isOpened():
# ```
#
# Agar kamera ochilmasa:
#
# ```python
# print("Could not open webcam")
# ```
#
# chiqariladi va dastur tugaydi.
#
# Bu foydalanuvchiga xatolik sababini tushuntiradi.
#
# ---
#
# # Starfield yaratish
#
# Kod
#
# ```python
# starfield = Starfield(
#     FRAME_W,
#     FRAME_H,
#     NUM_STARS
# )
# ```
#
# Bu obyekt fon uchun yulduzlarni yaratadi.
#
# ---
#
# # Trail yaratish
#
# Kod
#
# ```python
# trail = deque(maxlen=TRAIL_MAX_LEN)
# ```
#
# Trail — barmoqning oldingi koordinatalarini saqlaydi.
#
# Misol:
#
# ```
# •
#
# ••
#
# •••
#
# ••••
# ```
#
# `maxlen=40` bo'lsa, 40 ta nuqtadan ortig'i avtomatik o'chadi.
#
# ---
#
# # Shapes
#
# Kod
#
# ```python
# shapes = []
# ```
#
# Bu ro'yxatda barcha yaratilgan geometrik shakllar saqlanadi.
#
# Masalan:
#
# ```
# Ring
#
# Hexagon
#
# Ring
#
# Polygon
# ```
#
# ---
#
# # Pinch vaqti
#
# Kod
#
# ```python
# last_pinch_time = 0
# ```
#
# Oxirgi pinch qachon bo'lganini saqlaydi.
#
# Bu bir soniyada juda ko'p shape hosil bo'lishining oldini oladi.
#
# ---
#
# # Asosiy sikl
#
# Kod
#
# ```python
# while True:
# ```
#
# Bu dastur ishlayotgan vaqt davomida cheksiz takrorlanadi.
#
# Har aylanish:
#
# - yangi frame oladi
# - qo'lni aniqlaydi
# - effektlarni chizadi
# - ekranga chiqaradi
#
# ---
#
# # Kamera frame olish
#
# Kod
#
# ```python
# ok, frame = cap.read()
# ```
#
# `cap.read()` ikkita qiymat qaytaradi.
#
# ## ok
#
# ```
# True
# ```
#
# kamera muvaffaqiyatli ishlagan.
#
# ```
# False
# ```
#
# kamera xato bergan.
#
# ---
#
# ## frame
#
# Bu kameradan olingan rasm.
#
# OpenCV tasvirni **NumPy massiv** sifatida saqlaydi.
#
# Masalan:
#
# ```
# 540
#
# ×
#
# 960
#
# ×
#
# 3
# ```
#
# ---
#
# # Tekshirish
#
# Kod
#
# ```python
# if not ok:
#     break
# ```
#
# Agar frame olinmasa, dastur to'xtaydi.
#
# ---
#
# # Tasvirni aylantirish
#
# Kod
#
# ```python
# frame = cv2.flip(frame,1)
# ```
#
# `1` → gorizontal aylantirish.
#
# Oldin:
#
# ```
# Chap ← O'ng
# ```
#
# Keyin:
#
# ```
# O'ng ← Chap
# ```
#
# Bu oynadagi harakatni oynaga qaragandek qiladi.
#
# ---
#
# # Resize
#
# Kod
#
# ```python
# frame = cv2.resize(frame,(FRAME_W,FRAME_H))
# ```
#
# Har bir frame bir xil o'lchamga keltiriladi.
#
# ---
#
# # Canvas
#
# Kod
#
# ```python
# canvas = np.zeros_like(frame)
# ```
#
# Natijada qora fon hosil bo'ladi.
#
# ```
# ██████████
# ██████████
# ██████████
# ```
#
# Keyin yulduzlar shu yerga chiziladi.
#
# ---
#
# # Starfield
#
# Kod
#
# ```python
# starfield.draw(canvas)
# ```
#
# Fonni yulduzlar bilan to'ldiradi.
#
# ---
#
# # RGB ga o'tkazish
#
# Kod
#
# ```python
# rgb = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
# ```
#
# OpenCV:
#
# ```
# BGR
# ```
#
# MediaPipe:
#
# ```
# RGB
# ```
#
# Shuning uchun ranglar almashtiriladi.
#
# ---
#
# # Hand Detection
#
# Kod
#
# ```python
# results = hands.process(rgb)
# ```
#
# Bu AI modeliga rasmni yuboradi.
#
# Natijada:
#
# - qo'l bor
# - yoki yo'q
#
# aniqlanadi.
#
# ---
#
# # Glow Layer
#
# Kod
#
# ```python
# glow_layer = np.zeros_like(frame)
# ```
#
# Glow uchun alohida qatlam yaratiladi.
#
# Keyinchalik blur qilinadi.
#
# ---
#
# # Qo'l bormi?
#
# Kod
#
# ```python
# if results.multi_hand_landmarks:
# ```
#
# Agar qo'l topilgan bo'lsa, ichidagi kod ishlaydi.
#
# ---
#
# # Landmark
#
# Kod
#
# ```python
# hand_landmarks = results.multi_hand_landmarks[0]
# ```
#
# Birinchi qo'l olinadi.
#
# ---
#
# # Landmark ro'yxati
#
# Kod
#
# ```python
# lm = hand_landmarks.landmark
# ```
#
# Bu yerda 21 ta landmark mavjud.
#
# ```
# 0 Wrist
#
# 1 Thumb
#
# ...
#
# 4 Thumb Tip
#
# ...
#
# 8 Index Tip
#
# ...
#
# 20 Pinky
# ```
#
# ---
#
# # Index Finger
#
# Kod
#
# ```python
# index_tip = (
#     int(lm[8].x*FRAME_W),
#     int(lm[8].y*FRAME_H)
# )
# ```
#
# 8-raqamli landmark olinadi.
#
# Bu ko'rsatkich barmoq uchi.
#
# MediaPipe koordinatalari:
#
# ```
# 0
#
# ↓
#
# 1
# ```
#
# oralig'ida bo'ladi.
#
# Shuning uchun:
#
# ```python
# * FRAME_W
# ```
#
# va
#
# ```python
# * FRAME_H
# ```
#
# bilan piksel koordinatasiga o'tkaziladi.
#
# ---
#
# # Thumb
#
# Kod
#
# ```python
# thumb_tip = (
#     int(lm[4].x*FRAME_W),
#     int(lm[4].y*FRAME_H)
# )
# ```
#
# Bu bosh barmoq uchining koordinatasi.
#
# ---
#
# # Trail qo'shish
#
# Kod
#
# ```python
# trail.append(index_tip)
# ```
#
# Har frame yangi koordinata qo'shiladi.
#
# Natija:
#
# ```
# •
#
# ••
#
# •••
#
# ••••
# ```
#
# ---
#
# # Masofa hisoblash
#
# Kod
#
# ```python
# dist = math.hypot(
#     index_tip[0]-thumb_tip[0],
#     index_tip[1]-thumb_tip[1]
# )
# ```
#
# Formula:
#
# \[
# d=\sqrt{(x_2-x_1)^2+(y_2-y_1)^2}
# \]
#
# Bu ikki barmoq orasidagi haqiqiy masofani hisoblaydi.
#
# ---
#
# # Hozirgi vaqt
#
# Kod
#
# ```python
# now = time.time()
# ```
#
# Cooldown tekshirish uchun ishlatiladi.
#
# ---
#
# # Pinch Detection
#
# Kod
#
# ```python
# if dist < PINCH_THRESHOLD
# ```
#
# Agar ikki barmoq juda yaqin bo'lsa:
#
# ```
# 🤏
# ```
#
# Pinch bajarildi deb hisoblanadi.
#
# ---
#
# # Cooldown tekshirish
#
# Kod
#
# ```python
# (now-last_pinch_time)>PINCH_COOLDOWN
# ```
#
# Masalan:
#
# ```
# 0.6 sekund
# ```
#
# o'tmagan bo'lsa yangi shape yaratilmaydi.
#
# ---
#
# # Shape yaratish
#
# Kod
#
# ```python
# shapes.append(
#     WireShape(index_tip)
# )
# ```
#
# Pinch qilingan joyda yangi geometrik shakl hosil bo'ladi.
#
# ---
#
# # Oxirgi vaqtni saqlash
#
# Kod
#
# ```python
# last_pinch_time = now
# ```
#
# Keyingi pinch uchun vaqt yangilanadi.
#
# ---
#
# # Barmoqni chizish
#
# Kod
#
# ```python
# cv2.circle(
#     glow_layer,
#     index_tip,
#     6,
#     GLOW_COLOR,
#     -1,
#     cv2.LINE_AA
# )
# ```
#
# Ko'rsatkich barmoq uchiga kichik nurli doira chiziladi.
#
# ---
#
# # Qo'l yo'qolsa
#
# Kod
#
# ```python
# else:
# ```
#
# Agar qo'l topilmasa:
#
# ```python
# trail.popleft()
# ```
#
# Trail asta-sekin qisqaradi.
#
# Bu izning birdan yo'qolib ketmasligini ta'minlaydi.
#
# ---
#
# # Bo'lim xulosasi
#
# Bu bo'limda quyidagilarni o'rgandik:
#
# ✅ MediaPipe Hands modeli
#
# ✅ Webcam bilan ishlash
#
# ✅ Frame olish
#
# ✅ RGB va BGR farqi
#
# ✅ 21 ta Hand Landmark
#
# ✅ Index Finger va Thumb koordinatalari
#
# ✅ Masofa formulasi (`math.hypot()`)
#
# ✅ Pinch Detection
#
# ✅ Trail (`deque`)
#
# ✅ Shape yaratish
#
# ---
#
# ## Keyingi bo'lim
#
# **04_Main_Loop.md**
#
# Unda quyidagilar tushuntiriladi:
#
# - Trail chizish
# - Glow Layer
# - Shape Animation
# - Fade
# - addWeighted
# - cv2.imshow()
# - Keyboard Events (`q`, `c`)
# - Kamera yopish
# - `hands.close()`
# - Dasturning to'liq ishlash jarayoni

# %% [markdown]
# # 04_Main_Loop.md
#
# # 🔄 Main Loop (Asosiy sikl)
#
# Bu bo'limda `while True:` ichidagi qolgan kodlar batafsil tushuntiriladi.
#
# ---
#
# # Trail ni chizish
#
# Kod:
#
# ```python
# pts = list(trail)
# ```
#
# `trail` aslida `deque` hisoblanadi.
#
# Uni oddiy `list` ga aylantiramiz.
#
# Masalan:
#
# ```text
# trail
#
# ↓
#
# [(100,200),
#  (110,205),
#  (120,210),
#  (130,215)]
# ```
#
# ---
#
# # Nima uchun list qilamiz?
#
# Sababi indeks bilan ishlash osonroq.
#
# Masalan
#
# ```python
# pts[0]
#
# pts[1]
#
# pts[2]
# ```
#
# ---
#
# # Trail bo'ylab aylanish
#
# Kod
#
# ```python
# for i in range(1,len(pts)):
# ```
#
# Bu barcha nuqtalarni ketma-ket bog'laydi.
#
# Masalan
#
# ```
# A •────• B────• C────• D
# ```
#
# ---
#
# # Fade hisoblash
#
# Kod
#
# ```python
# fade = i / len(pts)
# ```
#
# Masalan
#
# ```
# 40 ta nuqta
# ```
#
# bo'lsa
#
# birinchisi
#
# ```
# 0.02
# ```
#
# oxirgisi
#
# ```
# 1.0
# ```
#
# Natijada eski nuqtalar xira,
#
# yangilari esa yorqin bo'ladi.
#
# ---
#
# # Thickness
#
# Kod
#
# ```python
# thickness = max(1,int(3*fade))
# ```
#
# Chiziq qalinligi.
#
# Misol
#
# ```
# 1 px
#
# 2 px
#
# 3 px
# ```
#
# Trail oxiriga yaqinroq qalinroq ko'rinadi.
#
# ---
#
# # Rang
#
# Kod
#
# ```python
# color = tuple(
#     int(c*fade)
#     for c in TRAIL_COLOR
# )
# ```
#
# Masalan
#
# ```
# (255,220,60)
# ```
#
# fade = 0.5 bo'lsa
#
# ```
# ↓
#
# (127,110,30)
# ```
#
# Natijada trail asta-sekin yo'qoladi.
#
# ---
#
# # Glow Line
#
# Kod
#
# ```python
# draw_glow_line(
#     glow_layer,
#     pts[i-1],
#     pts[i],
#     color,
#     thickness
# )
# ```
#
# Ikki nuqta orasiga chiziq chiziladi.
#
# ```
# •
#
# ──────
#
# •
# ```
#
# Barcha nuqtalar ulanganda
#
# ```
# ~~~~~~~~~~~~~
# ```
#
# ko'rinish hosil bo'ladi.
#
# ---
#
# # Shape larni tozalash
#
# Kod
#
# ```python
# shapes = [
#     s
#     for s in shapes
#     if s.alive()
# ]
# ```
#
# Bu juda muhim qator.
#
# Har bir shape tekshiriladi.
#
# Agar
#
# ```python
# alive()
# ```
#
# False bo'lsa
#
# ro'yxatdan chiqarib tashlanadi.
#
# ---
#
# # Nima uchun kerak?
#
# Aks holda
#
# 1000+
#
# shape yig'ilib qoladi.
#
# Natijada
#
# - RAM oshadi
# - FPS tushadi
#
# ---
#
# # Shape chizish
#
# Kod
#
# ```python
# for s in shapes:
# ```
#
# Barcha shape lar bo'yicha yuriladi.
#
# ---
#
# # Draw
#
# Kod
#
# ```python
# s.draw(glow_layer)
# ```
#
# Har bir shape
#
# - aylanadi
# - fade bo'ladi
# - glow beradi
#
# ---
#
# # Glow yaratish
#
# Kod
#
# ```python
# output = add_glow(
#     canvas,
#     glow_layer,
#     blur_ksize=15,
#     intensity=1.4
# )
# ```
#
# Bu loyiha ichidagi eng chiroyli effekt.
#
# Jarayon:
#
# ```
# Glow Layer
#
# ↓
#
# Gaussian Blur
#
# ↓
#
# Blurred Glow
#
# ↓
#
# Canvas bilan qo'shish
#
# ↓
#
# Natija
# ```
#
# ---
#
# # blur_ksize
#
# ```python
# 15
# ```
#
# Blur radiusi.
#
# Qiymat katta bo'lsa
#
# yorug'lik ko'proq tarqaladi.
#
# Masalan
#
# ```
# 5
#
# ↓
#
# 15
#
# ↓
#
# 31
# ```
#
# ---
#
# # intensity
#
# ```python
# 1.4
# ```
#
# Glow kuchi.
#
# Qiymat oshsa
#
# yorug'lik yanada kuchli ko'rinadi.
#
# ---
#
# # addWeighted
#
# Kod
#
# ```python
# output = cv2.addWeighted(
#     output,
#     1.0,
#     glow_layer,
#     0.6,
#     0
# )
# ```
#
# Bu glow ni yanada yorqin qiladi.
#
# Formula:
#
# ```
# Natija
#
# =
#
# 1.0 × Output
#
# +
#
# 0.6 × Glow Layer
# ```
#
# ---
#
# # Matn chiqarish
#
# Kod
#
# ```python
# cv2.putText(...)
# ```
#
# Bu oynaning pastiga yordamchi matn yozadi.
#
# Natija
#
# ```
# Pinch to spawn a shape
#
# 'c' clear
#
# 'q' quit
# ```
#
# ---
#
# # Parametrlar
#
# ```python
# cv2.putText(
# ```
#
# | Parametr | Ma'nosi |
# |-----------|----------|
# | output | Qaysi rasmga yozish |
# | Text | Yozuv |
# | (10,FRAME_H-15) | Joylashuvi |
# | FONT_HERSHEY_SIMPLEX | Shrift |
# | 0.5 | Shrift o'lchami |
# | Rang | Kulrang |
# | 1 | Qalinligi |
#
# ---
#
# # Natijani chiqarish
#
# Kod
#
# ```python
# cv2.imshow(
#     "Hand Magic",
#     output
# )
# ```
#
# OpenCV oynasi ochiladi.
#
# Har frame shu yerda ko'rsatiladi.
#
# ---
#
# # Klaviatura
#
# Kod
#
# ```python
# key = cv2.waitKey(1)&0xFF
# ```
#
# 1 millisekund kutadi.
#
# Agar foydalanuvchi tugma bossa
#
# ASCII kodi olinadi.
#
# ---
#
# # Chiqish
#
# Kod
#
# ```python
# if key in (
#     ord('q'),
#     27
# ):
# ```
#
# 27
#
# ESC tugmasi.
#
# ```
# Q
#
# yoki
#
# ESC
# ```
#
# bosilsa
#
# ```
# break
# ```
#
# ishlaydi.
#
# ---
#
# # Clear
#
# Kod
#
# ```python
# elif key == ord('c'):
# ```
#
# Agar
#
# ```
# C
# ```
#
# bosilsa
#
# shape lar tozalanadi.
#
# ---
#
# # Shapes clear
#
# Kod
#
# ```python
# shapes.clear()
# ```
#
# Barcha geometrik shakllar o'chiriladi.
#
# ---
#
# # Trail clear
#
# Kod
#
# ```python
# trail.clear()
# ```
#
# Barmoq izi ham o'chiriladi.
#
# ---
#
# # Kamera yopish
#
# Kod
#
# ```python
# cap.release()
# ```
#
# Webcam bo'shatiladi.
#
# Bu juda muhim.
#
# Aks holda boshqa dasturlar kamerani ishlata olmaydi.
#
# ---
#
# # Oynani yopish
#
# Kod
#
# ```python
# cv2.destroyAllWindows()
# ```
#
# OpenCV oynalari yopiladi.
#
# ---
#
# # MediaPipe ni yopish
#
# Kod
#
# ```python
# hands.close()
# ```
#
# AI modeli xotiradan chiqariladi.
#
# ---
#
# # Dasturni ishga tushirish
#
# Kod
#
# ```python
# if __name__=="__main__":
# ```
#
# Bu Python fayl to'g'ridan-to'g'ri ishga tushirilganda bajariladi.
#
# ---
#
# # main()
#
# Kod
#
# ```python
# main()
# ```
#
# Asosiy funksiyani ishga tushiradi.
#
# ---
#
# # Dastur qanday ishlaydi?
#
# ```text
# Programma
#
# ↓
#
# Webcam ochiladi
#
# ↓
#
# Frame olinadi
#
# ↓
#
# Frame RGB ga o'tadi
#
# ↓
#
# MediaPipe Hands ishlaydi
#
# ↓
#
# 21 ta landmark olinadi
#
# ↓
#
# Index Finger koordinatasi olinadi
#
# ↓
#
# Thumb koordinatasi olinadi
#
# ↓
#
# Masofa hisoblanadi
#
# ↓
#
# Pinch tekshiriladi
#
# ↓
#
# Trail yangilanadi
#
# ↓
#
# Shape yaratiladi
#
# ↓
#
# Glow Layer chiziladi
#
# ↓
#
# Blur qilinadi
#
# ↓
#
# Canvas bilan qo'shiladi
#
# ↓
#
# Natija monitorga chiqariladi
#
# ↓
#
# Keyingi frame...
# ```
#
# ---
#
# # Loyiha ichidagi asosiy obyektlar
#
# | Obyekt | Vazifasi |
# |---------|----------|
# | `VideoCapture` | Kameradan video olish |
# | `frame` | Kameradan kelgan rasm |
# | `canvas` | Yulduzli fon |
# | `glow_layer` | Glow effektlari |
# | `trail` | Barmoq izi |
# | `shapes` | Geometrik shakllar |
# | `MediaPipe Hands` | Qo'lni aniqlash |
# | `WireShape` | Sehrli shakllar |
# | `Starfield` | Fon yulduzlari |
#
# ---
#
# # Algoritm murakkabligi
#
# Har bir frame uchun:
#
# - ⭐ Yulduzlarni chizish → `O(NUM_STARS)`
# - ✨ Trail chizish → `O(TRAIL_MAX_LEN)`
# - 🔷 Shape chizish → `O(shapes)`
# - ✋ Hand Tracking → MediaPipe AI modeli
#
# Umumiy ishlash tezligi odatda real vaqt rejimida **30–60 FPS** atrofida bo'ladi (kompyuter imkoniyatiga qarab).
#
# ---
#
# # Nimalarni yaxshilash mumkin?
#
# - 🎇 Particle System qo'shish
# - 🔥 Fire Effect
# - ⚡ Lightning Effect
# - 🌈 Rangni gesture orqali o'zgartirish
# - ✋ Ikki qo'lni qo'llab-quvvatlash (`max_num_hands=2`)
# - 🎵 Ovoz effektlari
# - 🪄 Magic Wand modeli
# - 💾 Shape larni saqlash
# - 🎮 Mini o'yin yaratish
#
# ---
#
# # Xulosa
#
# Bu loyiha quyidagi texnologiyalarni birlashtiradi:
#
# - **OpenCV** — kamera va grafika
# - **MediaPipe Hands** — real vaqt qo'l kuzatuvi
# - **NumPy** — tasvirlar bilan ishlash
# - **Math** — masofa va aylanish hisoblari
# - **deque** — barmoq harakati tarixini saqlash
# - **Gaussian Blur** — glow effekti
# - **Alpha Blending** — qatlamlarni birlashtirish
# - **Object-Oriented Programming (OOP)** — `Starfield` va `WireShape` klasslari
#
# Natijada foydalanuvchi qo'l harakatlari bilan interaktiv, real vaqt rejimida ishlaydigan "Hand Magic" effektini yaratadigan zamonaviy Computer Vision loyihasi hosil bo'ladi.
