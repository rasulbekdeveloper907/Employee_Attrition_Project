# %% [markdown]
# # Datasetni yuklab olib Vizula Grafiklar orqali to`liq tanishib chiqamiz

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\Rasulbekk\Desktop\Employee_Attrition_Project\Data\Raw_Data\Employee_Attrition.csv")
