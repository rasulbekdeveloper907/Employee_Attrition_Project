# %% [markdown]
# # SML da arxitektura
# - Data Loading
# - EDA
# - Missing Values
# - Encoding
# - Train Test Split
# - Sampling
# - Feature Scaling
# - Feature Enginering
# - Feature Selection
# - Model Training
# - Hyperparameter Tuning
# - Model Evaluation
# - Save Model
# - Predict Model
# - DEPLOYMENT
